# %%
from NewTurtle import Turtle
t = Turtle();
t.penup()
t.speed(10)
t.right(90)
t.forward(150)
t.left(90)
t.backward(130)
t.pendown()
t.pencolor("white")
t.forward(260)
x=3
while x >0:
    t.circle(30,90)
    t.forward(260)
    x-=1
t.circle(30,90)

t.penup()
t.left(90)
t.forward(70)
t.right(90)
t.forward(70)

t.pendown()
t.pencolor("gold")
x=4
while x >0:
    t.forward(120)
    t.circle(30,90)
    x-=1
t.forward(60)
t.right(90)
t.pencolor("red")
t.forward(70)
t.penup()

t.backward(35)
t.left(90)
t.backward(20)

x=40
while x >0:
    t.forward(1)
    t.backward(1)
    x-=1

t.forward(140)


x=11
while x >0:
    t.left(90)
    t.forward(240)
    x-=1
t.left(90)
t.forward(142)
