# %%
from NewTurtle import Turtle
t = Turtle();
t.penup()
t.speed("fast")
t.right(90)
t.forward(150)
t.left(90)
t.backward(130)
t.pendown()
t.pencolor("white")
t.forward(260)
x=3
while x >0:
    t.circle(30,90)
    t.forward(260)
    x-=1
t.circle(30,90)

t.penup()
t.left(90)
t.forward(70)
t.right(90)
t.forward(70)

t.pendown()
t.pencolor("gold")
x=4
while x >0:
    t.forward(120)
    t.circle(30,90)
    x-=1
t.forward(60)
t.right(90)
t.pencolor("red")
t.forward(70)
t.penup()

t.backward(35)
t.left(90)
t.backward(20)

x=40
while x >0:
    t.forward(1)
    t.backward(1)
    x-=1

t.forward(140)


x=11
while x >0:
    t.left(90)
    t.forward(240)
    x-=1
t.left(90)
t.forward(142)
# Out:
# TURTLE 1 black 200 200 0 1
# TURTLE 0 black 200 200 90 2
# TURTLE 0 black 200.0 350.0 0 2
# TURTLE 0 black 200.0 350.0 -90 2
# TURTLE 0 black 70.0 350.0 0 2
# TURTLE 1 white 330.0 350.0 0 2
# TURTLE 1 white 330.0 350.0 0 2
# TURTLE 1 white 330.0 350.0 -2 2
# TURTLE 1 white 331.046559627 349.963453333 0 2
# TURTLE 1 white 331.046559627 349.963453333 -2 2
# TURTLE 1 white 332.091206257 349.890404524 0 2
# TURTLE 1 white 332.091206257 349.890404524 -2 2
# TURTLE 1 white 333.132667151 349.780942573 0 2
# TURTLE 1 white 333.132667151 349.780942573 -2 2
# TURTLE 1 white 334.169673447 349.635200843 0 2
# TURTLE 1 white 334.169673447 349.635200843 -2 2
# TURTLE 1 white 335.200961715 349.453356896 0 2
# TURTLE 1 white 335.200961715 349.453356896 -2 2
# TURTLE 1 white 336.225275487 349.235632283 0 2
# TURTLE 1 white 336.225275487 349.235632283 -2 2
# TURTLE 1 white 337.241366795 348.982292266 0 2
# TURTLE 1 white 337.241366795 348.982292266 -2 2
# ...
